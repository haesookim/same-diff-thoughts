# %%
import pandas as pd
import numpy as np

# set of column names
headerNames = ["q1", "q2", "q3", "q4", "q5", "q6", "q7","q8", "q9", "q10", "gender", "age", "polAlign"]

# read csv-converted data from excel file
# current data is cleaned to exclude empty and/or meaningless columns
answerData = pd.read_csv('data/50data_answeronly.csv', header =0, names=headerNames)

# save number of entries
dataCount = len(answerData.index)

answerData
# Out:
#          q1       q2       q3       q4       q5       q6       q7       q8  \
# 0      ③ 중립  ① 매우 찬성     ② 찬성     ④ 반대     ② 찬성  ① 매우 찬성     ③ 중립     ② 찬성
# 1   ① 매우 찬성     ③ 중립     ② 찬성     ② 찬성  ⑤ 매우 반대     ④ 반대     ② 찬성     ④ 반대
# 2      ② 찬성  ⑤ 매우 반대     ③ 중립     ② 찬성  ① 매우 찬성     ④ 반대     ② 찬성     ③ 중립
# 3   ⑤ 매우 반대     ② 찬성     ④ 반대  ⑤ 매우 반대  ① 매우 찬성     ④ 반대  ① 매우 찬성  ① 매우 찬성
# 4      ③ 중립     ③ 중립     ③ 중립     ③ 중립     ② 찬성     ③ 중립     ③ 중립     ③ 중립
# 5      ② 찬성     ④ 반대     ② 찬성     ④ 반대     ② 찬성     ④ 반대     ② 찬성     ④ 반대
# 6   ① 매우 찬성     ④ 반대     ② 찬성     ③ 중립  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대     ② 찬성
# 7      ② 찬성  ① 매우 찬성     ② 찬성     ② 찬성     ④ 반대     ③ 중립     ③ 중립     ② 찬성
# 8      ④ 반대     ② 찬성  ⑤ 매우 반대     ④ 반대     ④ 반대     ④ 반대     ④ 반대  ① 매우 찬성
# 9   ⑤ 매우 반대     ③ 중립  ⑤ 매우 반대  ⑤ 매우 반대  ① 매우 찬성     ② 찬성     ② 찬성     ② 찬성
# 10  ① 매우 찬성  ① 매우 찬성     ④ 반대     ④ 반대     ④ 반대  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성
# 11  ① 매우 찬성     ③ 중립  ⑤ 매우 반대     ④ 반대  ① 매우 찬성     ③ 중립     ② 찬성  ① 매우 찬성
# 12  ⑤ 매우 반대     ② 찬성  ① 매우 찬성     ② 찬성     ④ 반대     ② 찬성     ② 찬성  ⑤ 매우 반대
# 13  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대     ③ 중립
# 14  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ③ 중립     ④ 반대  ① 매우 찬성  ⑤ 매우 반대     ④ 반대
# 15  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대  ① 매우 찬성     ④ 반대  ① 매우 찬성  ① 매우 찬성
# 16     ④ 반대  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ③ 중립  ⑤ 매우 반대  ① 매우 찬성
# 17  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ③ 중립  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대     ④ 반대
# 18     ② 찬성     ② 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대
# 19     ② 찬성  ① 매우 찬성     ② 찬성     ② 찬성  ① 매우 찬성  ① 매우 찬성     ③ 중립  ⑤ 매우 반대
# 20     ③ 중립     ④ 반대     ③ 중립     ② 찬성     ③ 중립     ② 찬성     ③ 중립     ③ 중립
# 21     ② 찬성     ② 찬성     ② 찬성     ② 찬성  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성
# 22  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ② 찬성  ① 매우 찬성     ③ 중립     ③ 중립     ③ 중립
# 23     ③ 중립  ① 매우 찬성     ③ 중립  ⑤ 매우 반대  ① 매우 찬성     ④ 반대  ⑤ 매우 반대     ③ 중립
# 24     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ② 찬성     ③ 중립     ③ 중립     ③ 중립
# 25     ④ 반대  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ② 찬성     ③ 중립  ① 매우 찬성
# 26  ⑤ 매우 반대     ③ 중립     ③ 중립  ⑤ 매우 반대     ② 찬성  ⑤ 매우 반대     ③ 중립  ⑤ 매우 반대
# 27     ③ 중립  ① 매우 찬성     ③ 중립     ③ 중립  ① 매우 찬성  ① 매우 찬성     ② 찬성  ⑤ 매우 반대
# 28  ① 매우 찬성  ① 매우 찬성     ③ 중립     ④ 반대  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대     ④ 반대
# 29  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대     ② 찬성     ③ 중립     ② 찬성  ① 매우 찬성
# 30  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성     ③ 중립  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성
# 31     ④ 반대  ⑤ 매우 반대     ③ 중립  ① 매우 찬성  ① 매우 찬성     ④ 반대  ① 매우 찬성  ① 매우 찬성
# 32     ④ 반대  ① 매우 찬성  ⑤ 매우 반대     ③ 중립     ② 찬성     ④ 반대  ① 매우 찬성  ① 매우 찬성
# 33  ① 매우 찬성     ③ 중립  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대
# 34  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ① 매우 찬성
# 35     ③ 중립     ③ 중립  ① 매우 찬성     ③ 중립  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대     ④ 반대
# 36  ① 매우 찬성     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ② 찬성  ⑤ 매우 반대  ⑤ 매우 반대
# 37  ① 매우 찬성     ③ 중립  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대
# 38     ② 찬성     ③ 중립     ③ 중립  ⑤ 매우 반대  ⑤ 매우 반대     ④ 반대  ⑤ 매우 반대     ③ 중립
# 39  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성     ③ 중립  ⑤ 매우 반대
# 40     ③ 중립     ② 찬성     ③ 중립     ④ 반대     ③ 중립     ③ 중립     ③ 중립  ① 매우 찬성
# 41  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대     ④ 반대  ⑤ 매우 반대     ④ 반대  ⑤ 매우 반대  ⑤ 매우 반대
# 42  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대  ⑤ 매우 반대
# 43     ③ 중립  ① 매우 찬성     ③ 중립     ③ 중립     ② 찬성     ③ 중립     ④ 반대     ② 찬성
# 44  ① 매우 찬성  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대  ① 매우 찬성  ① 매우 찬성  ⑤ 매우 반대     ③ 중립
# 45  ⑤ 매우 반대  ① 매우 찬성     ④ 반대     ② 찬성     ③ 중립     ② 찬성     ② 찬성     ③ 중립
# 46     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ③ 중립     ③ 중립
# 47     ② 찬성     ④ 반대     ③ 중립  ⑤ 매우 반대     ④ 반대     ③ 중립     ④ 반대     ④ 반대
# 48     ② 찬성     ② 찬성     ② 찬성  ① 매우 찬성     ② 찬성  ① 매우 찬성     ② 찬성     ② 찬성
# 49  ⑤ 매우 반대  ① 매우 찬성  ⑤ 매우 반대     ③ 중립  ① 매우 찬성  ⑤ 매우 반대  ⑤ 매우 반대  ① 매우 찬성
#
#          q9      q10 gender  age  polAlign
# 0      ③ 중립     ② 찬성      남   40         2
# 1      ③ 중립  ① 매우 찬성      여   25         2
# 2   ⑤ 매우 반대     ② 찬성      남   31         3
# 3   ⑤ 매우 반대     ③ 중립      남   51         4
# 4      ③ 중립     ③ 중립      여   38         3
# 5      ② 찬성     ③ 중립      여   47         3
# 6   ① 매우 찬성     ② 찬성      여   21         2
# 7      ③ 중립  ① 매우 찬성      남   32         3
# 8   ① 매우 찬성  ① 매우 찬성      여   52         4
# 9      ④ 반대  ① 매우 찬성      남   56         5
# 10  ① 매우 찬성  ① 매우 찬성      여   50         4
# 11     ③ 중립  ① 매우 찬성      남   58         4
# 12  ⑤ 매우 반대     ② 찬성      여   49         4
# 13  ① 매우 찬성  ① 매우 찬성      남   25         4
# 14  ① 매우 찬성     ② 찬성      남   19         2
# 15  ⑤ 매우 반대  ① 매우 찬성      남   68         5
# 16     ② 찬성  ① 매우 찬성      남   22         5
# 17  ① 매우 찬성     ③ 중립      남   28         1
# 18  ⑤ 매우 반대     ② 찬성      여   28         2
# 19     ② 찬성     ② 찬성      여   37         2
# 20     ④ 반대     ③ 중립      남   43         3
# 21     ④ 반대  ① 매우 찬성      남   26         4
# 22  ① 매우 찬성  ① 매우 찬성      남   36         1
# 23  ① 매우 찬성  ① 매우 찬성      여   25         2
# 24     ③ 중립     ② 찬성      남   43         3
# 25  ① 매우 찬성  ① 매우 찬성      남   24         5
# 26  ① 매우 찬성     ② 찬성      남   32         3
# 27  ① 매우 찬성     ③ 중립      여   48         4
# 28     ② 찬성     ③ 중립      여   26         3
# 29  ⑤ 매우 반대     ④ 반대      여   68         3
# 30  ① 매우 찬성     ② 찬성      여   25         4
# 31  ⑤ 매우 반대     ④ 반대      남   47         2
# 32  ⑤ 매우 반대     ③ 중립      남   63         4
# 33  ① 매우 찬성     ② 찬성      여   23         1
# 34  ⑤ 매우 반대     ② 찬성      남   65         5
# 35  ① 매우 찬성     ② 찬성      남   24         3
# 36  ① 매우 찬성  ① 매우 찬성      여   39         1
# 37  ① 매우 찬성  ① 매우 찬성      여   19         1
# 38     ② 찬성  ⑤ 매우 반대      남   60         3
# 39  ① 매우 찬성  ① 매우 찬성      여   37         1
# 40     ③ 중립     ③ 중립      남   45         3
# 41     ④ 반대  ⑤ 매우 반대      남   65         5
# 42  ⑤ 매우 반대  ① 매우 찬성      남   56         4
# 43     ② 찬성  ① 매우 찬성      여   57         3
# 44     ④ 반대  ① 매우 찬성      여   48         2
# 45     ② 찬성     ③ 중립      여   58         3
# 46     ③ 중립     ③ 중립      남   20         3
# 47  ① 매우 찬성     ④ 반대      남   39         2
# 48  ① 매우 찬성  ① 매우 찬성      남   25         2
# 49  ⑤ 매우 반대  ① 매우 찬성      남   45         5

# %%
# replace all redundant text to interger values

answerData.replace(["① 매우 찬성","② 찬성", "③ 중립", "④ 반대", "⑤ 매우 반대", "남", "여"], [1, 2, 3, 4, 5, "M", "F"], inplace = True)


# add new columns to denote how many times it has been assigned to pairs

answerData["same"] = [0]*dataCount
answerData["diff"] = [0]*dataCount

answerData
# Out:
#     q1  q2  q3  q4  q5  q6  q7  q8  q9  q10 gender  age  polAlign  same  diff
# 0    3   1   2   4   2   1   3   2   3    2      M   40         2     0     0
# 1    1   3   2   2   5   4   2   4   3    1      F   25         2     0     0
# 2    2   5   3   2   1   4   2   3   5    2      M   31         3     0     0
# 3    5   2   4   5   1   4   1   1   5    3      M   51         4     0     0
# 4    3   3   3   3   2   3   3   3   3    3      F   38         3     0     0
# 5    2   4   2   4   2   4   2   4   2    3      F   47         3     0     0
# 6    1   4   2   3   5   1   5   2   1    2      F   21         2     0     0
# 7    2   1   2   2   4   3   3   2   3    1      M   32         3     0     0
# 8    4   2   5   4   4   4   4   1   1    1      F   52         4     0     0
# 9    5   3   5   5   1   2   2   2   4    1      M   56         5     0     0
# 10   1   1   4   4   4   1   5   1   1    1      F   50         4     0     0
# 11   1   3   5   4   1   3   2   1   3    1      M   58         4     0     0
# 12   5   2   1   2   4   2   2   5   5    2      F   49         4     0     0
# 13   1   1   1   1   5   1   5   3   1    1      M   25         4     0     0
# 14   1   1   1   3   4   1   5   4   1    2      M   19         2     0     0
# 15   5   1   5   5   1   4   1   1   5    1      M   68         5     0     0
# 16   4   1   1   1   1   3   5   1   2    1      M   22         5     0     0
# 17   1   1   1   3   5   1   5   4   1    3      M   28         1     0     0
# 18   2   2   1   1   1   1   5   5   5    2      F   28         2     0     0
# 19   2   1   2   2   1   1   3   5   2    2      F   37         2     0     0
# 20   3   4   3   2   3   2   3   3   4    3      M   43         3     0     0
# 21   2   2   2   2   5   1   5   1   4    1      M   26         4     0     0
# 22   1   1   1   2   1   3   3   3   1    1      M   36         1     0     0
# 23   3   1   3   5   1   4   5   3   1    1      F   25         2     0     0
# 24   3   3   3   3   2   3   3   3   3    2      M   43         3     0     0
# 25   4   1   1   1   1   2   3   1   1    1      M   24         5     0     0
# 26   5   3   3   5   2   5   3   5   1    2      M   32         3     0     0
# 27   3   1   3   3   1   1   2   5   1    3      F   48         4     0     0
# 28   1   1   3   4   5   1   5   4   2    3      F   26         3     0     0
# 29   1   1   5   5   2   3   2   1   5    4      F   68         3     0     0
# 30   1   1   1   1   3   1   1   1   1    2      F   25         4     0     0
# 31   4   5   3   1   1   4   1   1   5    4      M   47         2     0     0
# 32   4   1   5   3   2   4   1   1   5    3      M   63         4     0     0
# 33   1   3   1   5   1   1   5   5   1    2      F   23         1     0     0
# 34   5   5   5   5   1   5   1   1   5    2      M   65         5     0     0
# 35   3   3   1   3   1   5   5   4   1    2      M   24         3     0     0
# 36   1   3   3   3   3   2   5   5   1    1      F   39         1     0     0
# 37   1   3   1   1   5   1   5   5   1    1      F   19         1     0     0
# 38   2   3   3   5   5   4   5   3   2    5      M   60         3     0     0
# 39   1   5   1   1   5   1   3   5   1    1      F   37         1     0     0
# 40   3   2   3   4   3   3   3   1   3    3      M   45         3     0     0
# 41   5   5   5   4   5   4   5   5   4    5      M   65         5     0     0
# 42   5   1   5   5   5   5   5   5   5    1      M   56         4     0     0
# 43   3   1   3   3   2   3   4   2   2    1      F   57         3     0     0
# 44   1   1   1   5   1   1   5   3   4    1      F   48         2     0     0
# 45   5   1   4   2   3   2   2   3   2    3      F   58         3     0     0
# 46   3   3   3   3   3   3   3   3   3    3      M   20         3     0     0
# 47   2   4   3   5   4   3   4   4   1    4      M   39         2     0     0
# 48   2   2   2   1   2   1   2   2   1    1      M   25         2     0     0
# 49   5   1   5   3   1   5   5   1   5    1      M   45         5     0     0

# %%
# create a new dataframe to save values
# this will be very time and cost extensive, might be viable to change this part
# will be durable for several hundred calculations though...?

diffMatrix = pd.DataFrame(np.nan, index=range(dataCount), columns=range(dataCount), dtype='float')

# %%
for i in range(dataCount):
    for j in range(i, dataCount):
        tempVal=0;
        if (i==j):
            diffMatrix.iloc[i][j] = np.nan
            continue
        for k in range(10):
            # iterates through 10 for the number of questions in the dataframe
            tempVal += answerData.iloc[i][k]-answerData.iloc[j][k]
        # Assign same value to the flipped index to save computation time
        diffMatrix.iloc[i][j] = abs(tempVal)
        diffMatrix.iloc[j][i] = abs(tempVal)

# Calculate the median value of all the diff values (currently, it's 5)
diffMedian = diffMatrix.stack().median()

# %%
matchSame = []
matchDiff = []

for i in range(dataCount-1):
    # Shallow copy the current row to mutate
    tempArray = list(diffMatrix[i][i+1:dataCount]) #split array to prevent double matches
    
    j = 0
    while j < 3:
        tempSame = np.argmin(tempArray) # Return index of the current minumum diff individual
        if (tempArray[tempSame] > diffMedian):
            # if the current min value is larger than the median Diff, stop searching  
            break
        elif (answerData.iloc[i]["same"] >= 3):
            # if the match count for the current row is already over 3, stop searching
            break
        elif (answerData.iloc[tempSame+i]["same"] < 3):
            # if the current match count for both items are less than 3, provide match
            matchSame.append([i, tempSame+i+1])
            
            # this part isn't working right now
            answerData.iloc[i]["same"] += 1
            answerData.iloc[tempSame+i]["same"] +=1
            
            tempArray[tempSame] = 100
            # replace tempArray value to a large number that will not be min-ed
            j += 1 
        else: 
            # is there an alternative thing?
            j += 1

matchSame
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# [[0, 7],
#  [0, 10],
#  [0, 14],
#  [1, 23],
#  [1, 36],
#  [1, 45],
#  [2, 4],
#  [2, 5],
#  [2, 15],
#  [3, 8],
#  [3, 9],
#  [3, 12],
#  [4, 5],
#  [4, 15],
#  [4, 28],
#  [5, 15],
#  [5, 28],
#  [5, 29],
#  [6, 17],
#  [6, 18],
#  [6, 21],
#  [7, 10],
#  [7, 14],
#  [7, 27],
#  [8, 9],
#  [8, 12],
#  [8, 20],
#  [9, 12],
#  [9, 20],
#  [9, 46],
#  [10, 14],
#  [10, 27],
#  [10, 44],
#  [11, 37],
#  [11, 39],
#  [11, 43],
#  [12, 20],
#  [12, 46],
#  [12, 15],
#  [13, 16],
#  [13, 19],
#  [13, 14],
#  [14, 27],
#  [14, 44],
#  [14, 37],
#  [15, 28],
#  [15, 29],
#  [15, 31],
#  [16, 19],
#  [16, 22],
#  [16, 27],
#  [17, 18],
#  [17, 21],
#  [17, 33],
#  [18, 21],
#  [18, 33],
#  [18, 37],
#  [19, 27],
#  [19, 44],
#  [19, 37],
#  [20, 46],
#  [20, 28],
#  [20, 29],
#  [21, 33],
#  [21, 37],
#  [21, 39],
#  [22, 25],
#  [22, 48],
#  [22, 30],
#  [23, 36],
#  [23, 45],
#  [23, 24],
#  [24, 35],
#  [24, 40],
#  [24, 28],
#  [25, 48],
#  [25, 30],
#  [26, 47],
#  [26, 34],
#  [26, 49],
#  [27, 44],
#  [27, 37],
#  [27, 39],
#  [28, 29],
#  [28, 31],
#  [28, 32],
#  [29, 31],
#  [29, 32],
#  [29, 35],
#  [30, 48],
#  [31, 32],
#  [31, 35],
#  [31, 40],
#  [32, 35],
#  [32, 40],
#  [32, 46],
#  [33, 37],
#  [33, 39],
#  [33, 43],
#  [34, 47],
#  [34, 38],
#  [34, 49],
#  [35, 40],
#  [35, 36],
#  [35, 45],
#  [36, 45],
#  [36, 40],
#  [36, 37],
#  [37, 39],
#  [37, 43],
#  [37, 44],
#  [38, 47],
#  [38, 42],
#  [38, 49],
#  [39, 43],
#  [39, 44],
#  [39, 45],
#  [40, 45],
#  [40, 46],
#  [40, 43],
#  [41, 42],
#  [43, 44],
#  [43, 45],
#  [44, 45],
#  [45, 46],
#  [45, 49],
#  [46, 49],
#  [46, 47],
#  [47, 49]]

# %%
answerData
# Out:
#     q1  q2  q3  q4  q5  q6  q7  q8  q9  q10 gender  age  polAlign  same  diff
# 0    3   1   2   4   2   1   3   2   3    2      M   40         2     0     0
# 1    1   3   2   2   5   4   2   4   3    1      F   25         2     0     0
# 2    2   5   3   2   1   4   2   3   5    2      M   31         3     0     0
# 3    5   2   4   5   1   4   1   1   5    3      M   51         4     0     0
# 4    3   3   3   3   2   3   3   3   3    3      F   38         3     0     0
# 5    2   4   2   4   2   4   2   4   2    3      F   47         3     0     0
# 6    1   4   2   3   5   1   5   2   1    2      F   21         2     0     0
# 7    2   1   2   2   4   3   3   2   3    1      M   32         3     0     0
# 8    4   2   5   4   4   4   4   1   1    1      F   52         4     0     0
# 9    5   3   5   5   1   2   2   2   4    1      M   56         5     0     0
# 10   1   1   4   4   4   1   5   1   1    1      F   50         4     0     0
# 11   1   3   5   4   1   3   2   1   3    1      M   58         4     0     0
# 12   5   2   1   2   4   2   2   5   5    2      F   49         4     0     0
# 13   1   1   1   1   5   1   5   3   1    1      M   25         4     0     0
# 14   1   1   1   3   4   1   5   4   1    2      M   19         2     0     0
# 15   5   1   5   5   1   4   1   1   5    1      M   68         5     0     0
# 16   4   1   1   1   1   3   5   1   2    1      M   22         5     0     0
# 17   1   1   1   3   5   1   5   4   1    3      M   28         1     0     0
# 18   2   2   1   1   1   1   5   5   5    2      F   28         2     0     0
# 19   2   1   2   2   1   1   3   5   2    2      F   37         2     0     0
# 20   3   4   3   2   3   2   3   3   4    3      M   43         3     0     0
# 21   2   2   2   2   5   1   5   1   4    1      M   26         4     0     0
# 22   1   1   1   2   1   3   3   3   1    1      M   36         1     0     0
# 23   3   1   3   5   1   4   5   3   1    1      F   25         2     0     0
# 24   3   3   3   3   2   3   3   3   3    2      M   43         3     0     0
# 25   4   1   1   1   1   2   3   1   1    1      M   24         5     0     0
# 26   5   3   3   5   2   5   3   5   1    2      M   32         3     0     0
# 27   3   1   3   3   1   1   2   5   1    3      F   48         4     0     0
# 28   1   1   3   4   5   1   5   4   2    3      F   26         3     0     0
# 29   1   1   5   5   2   3   2   1   5    4      F   68         3     0     0
# 30   1   1   1   1   3   1   1   1   1    2      F   25         4     0     0
# 31   4   5   3   1   1   4   1   1   5    4      M   47         2     0     0
# 32   4   1   5   3   2   4   1   1   5    3      M   63         4     0     0
# 33   1   3   1   5   1   1   5   5   1    2      F   23         1     0     0
# 34   5   5   5   5   1   5   1   1   5    2      M   65         5     0     0
# 35   3   3   1   3   1   5   5   4   1    2      M   24         3     0     0
# 36   1   3   3   3   3   2   5   5   1    1      F   39         1     0     0
# 37   1   3   1   1   5   1   5   5   1    1      F   19         1     0     0
# 38   2   3   3   5   5   4   5   3   2    5      M   60         3     0     0
# 39   1   5   1   1   5   1   3   5   1    1      F   37         1     0     0
# 40   3   2   3   4   3   3   3   1   3    3      M   45         3     0     0
# 41   5   5   5   4   5   4   5   5   4    5      M   65         5     0     0
# 42   5   1   5   5   5   5   5   5   5    1      M   56         4     0     0
# 43   3   1   3   3   2   3   4   2   2    1      F   57         3     0     0
# 44   1   1   1   5   1   1   5   3   4    1      F   48         2     0     0
# 45   5   1   4   2   3   2   2   3   2    3      F   58         3     0     0
# 46   3   3   3   3   3   3   3   3   3    3      M   20         3     0     0
# 47   2   4   3   5   4   3   4   4   1    4      M   39         2     0     0
# 48   2   2   2   1   2   1   2   2   1    1      M   25         2     0     0
# 49   5   1   5   3   1   5   5   1   5    1      M   45         5     0     0
